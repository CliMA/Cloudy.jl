# %% [markdown]
# [![View notebook](https://img.shields.io/static/v1?label=render%20on&logo=github&color=87ce3e&message=GitHub)](https://github.com/open-atmos/PySDM/blob/main/examples/PySDM_examples/deJong_Azimi/rainshaft.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/open-atmos/PySDM.git/main?urlpath=examples/PySDM_examples/deJong_Azimi/rainshaft.ipynb)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/open-atmos/PySDM/blob/main/examples/PySDM_examples/deJong_Azimi/rainshaft.ipynb)

# %% [markdown]
# #### Derived from the precipitation case of Fig. 1 from Shipway & Hill 2012, but with no condensation/evaporation (collisions only). For further information, see Shipway_Hill_2012 example.
#
# **NOTES**:
# - constant momentum profile rather than constant velocity profile is used herein
# - sedimentation and collisions are the only active dynamics
# - pressure at z=0 not given in the paper, assumed (see settings.py)
# - domain extended below z=0 to mimic particle inflow via updraft

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip --quiet install open-atmos-jupyter-utils
    from open_atmos_jupyter_utils import pip_install_on_colab
    pip_install_on_colab('PySDM-examples')

# %%
from PySDM_examples.Shipway_and_Hill_2012 import plot, Simulation, Settings
from PySDM_examples.deJong_Azimi import Settings1D
from open_atmos_jupyter_utils import show_plot
from PySDM.physics import si, in_unit
from PySDM.exporters import NetCDFExporter_1d
from matplotlib import pyplot
import xarray as xr

# %% [markdown]
# ## Partial Domain Collisions Only Test Case

# %%
common_params = {
    "n_sd_per_gridbox": 256,
    "dt": 10 * si.s,
    "dz": 150 * si.m,
    "particles_per_volume_STP": 10 / si.cm**3,
    "t_max": 3600 * si.s,
}
output = {}
settings = {}
simulation = {}
for rho_times_w in (
    0 * si.kg/si.m**3 * si.m/si.s,
):
    key = f"rhow={rho_times_w}"
    settings[key] = Settings1D(
        **common_params,
        rho_times_w_1=rho_times_w,
    )
    simulation[key] = Simulation(settings[key])
    output[key] = simulation[key].run().products

# %%
for rho_times_w in (0,):
    plot(var='cloud water mixing ratio', qlabel='cloud water mixing ratio [g/kg]', fname=f'qc_rhow={rho_times_w}.pdf',
            output=output[f'rhow={rho_times_w}.0'],
            line = {0: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./qc_rhow=0.pdf' target='_blank'>./qc_rhow=0.pdf</a><br>")

# %%
for rho_times_w in (0,):
    plot(var='nc', qlabel='cloud water number concentration', fname=f'nc_rhow={rho_times_w}.pdf',
            output=output[f'rhow={rho_times_w}.0'],
            line = {0.01: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./nc_rhow=0.pdf' target='_blank'>./nc_rhow=0.pdf</a><br>")

# %%
p = True
for rho_times_w in (0,):
    plot(var='rain water mixing ratio', qlabel='rain water mixing ratio [g/kg]', fname=f'qr_rhow={rho_times_w}.pdf',
         output=output[f'rhow={rho_times_w}.0'],
         line = {0: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./qr_rhow=0.pdf' target='_blank'>./qr_rhow=0.pdf</a><br>")

# %%
for rho_times_w in (0,):
    plot(var='nr', qlabel='rain water number concentration', fname=f'nr_rhow={rho_times_w}.pdf',
            output=output[f'rhow={rho_times_w}.0'],
            line = {0.01: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./nr_rhow=0.pdf' target='_blank'>./nr_rhow=0.pdf</a><br>")

# %% [markdown]
# ## Partial Domain Collisions Test Case
# Including comparisons

# %%
p = True
for rho_times_w in (0,):
    key = f"rhow={rho_times_w}.0"
    filename = 'products_' + key + 'collisions.nc'
    nc_exporter = NetCDFExporter_1d(output[key], settings[key], simulation[key], filename)
    nc_exporter.run()

# %%
cloudy.close()
cloudy = xr.open_dataset("rainshaft_double_gamma.nc")

# %%
cloudy['Nr'].max()
# Out:
# <xarray.DataArray 'Nr' ()>
# array(426611.02214497)

# %%
plt_times = [0, 250, 500, 1000]
dt = common_params["dt"]
dz = common_params["dz"] / 1000

(fig, ax) = pyplot.subplots(nrows=2, ncols=2, sharey=True, figsize=(9,7), tight_layout=True)
for (j,t) in enumerate(plt_times):
    it = int(t / dt)
    profiles = output[f'rhow={rho_times_w}.0']
    nc = profiles['nc'][:,it]
    nr = profiles['nr'][:,it]
    qc_g_kg = profiles['cloud water mixing ratio'][:,it]
    qr_g_kg = profiles['rain water mixing ratio'][:,it]

    if j == 0:
        lbl = 't=0, PySDM'
        lbl2 = 't=0, Cloudy.jl'
    else:
        lbl = 't='+str(t)+'s'
        lbl2 = '_'
    line = ax[0][0].plot(
        in_unit(nc, si.cm**-3),
        in_unit(profiles['z'], si.km),
        label=lbl
    )
    ax[0][0].plot(
        in_unit(cloudy['Nc'][:,t], si.cm**(-3)),
        in_unit(cloudy['altitude'], si.km),
        '--',
        color=line[-1].get_color(),
        label=lbl2
    )
    line = ax[0][1].plot(
        in_unit(nr, si.cm**-3),
        in_unit(profiles['z'], si.km)
    )
    ax[0][1].plot(
        in_unit(cloudy['Nr'][:,t], si.cm**(-3)),
        in_unit(cloudy['altitude'], si.km),
        '--',
        color=line[-1].get_color()
    )
    line = ax[1][0].plot(
        qc_g_kg,
        in_unit(profiles['z'], si.km)
    )
    ax[1][0].plot(
        in_unit(cloudy['Mc'][:,t], si.g),
        in_unit(cloudy['altitude'], si.km),
        '--',
        color=line[-1].get_color()
    )
    line = ax[1][1].plot(
        qr_g_kg,
        in_unit(profiles['z'], si.km)
    )
    ax[1][1].plot(
        in_unit(cloudy['Mr'][:,t], si.g),
        in_unit(cloudy['altitude'], si.km),
        '--',
        color=line[-1].get_color()
    )

ax[1][0].set_xlim([-0.05, 1.05])
ax[1][1].set_xlim([-0.05, 1.05])
ax[0][0].set_xlabel('N_c (cm$^{-3}$)')
ax[0][0].set_ylabel('z (km)')
ax[0][0].legend()
ax[0][1].set_xlabel('N_r (cm$^{-3}$)')
ax[1][0].set_xlabel('q_c (g kg$^{-1}$)')
ax[1][0].set_ylabel('z (km)')
ax[1][1].set_xlabel('q_r (g kg$^{-1}$)')

show_plot('rainshaft.pdf')
# Out:
# HTML(value="<a href='./rainshaft.pdf' target='_blank'>./rainshaft.pdf</a><br>")

# %% [markdown]
# # All dynamics test case
# See analysis in the package `KinematicDriver.jl`

# %%
from PySDM.dynamics.collisions.collision_kernels import Golovin, SimpleGeometric
from PySDM import Formulae
import numpy as np

# %%
common_params = {
    "n_sd_per_gridbox": 256,
    "dt": 5 * si.s,
    "dz": 50 * si.m,
    "particles_per_volume_STP": 100 / si.cm**3,
    "t_max": 3600 * si.s,
    "p0": 990 * si.hPa,
    "kappa": .9,
    "z_max": 2000 * si.m,
}
output = {}
settings = {}
simulation = {}
for rho_times_w in (
    2 * si.kg/si.m**3 * si.m/si.s,
):
    key = f"rhow={rho_times_w}"
    settings[key] = Settings(
        **common_params,
        rho_times_w_1=rho_times_w,
        formulae=Formulae(terminal_velocity="PowerSeries"),
        collision_kernel=Golovin(b=5e3), #SimpleGeometric(C=1e-6*np.pi) #
    )
    simulation[key] = Simulation(settings[key])
    output[key] = simulation[key].run().products

# %%
output[key]['rain_rate'] * 1e3 * 3600
# Out:
# array([0.00000000e+00, 7.88925740e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        5.11368660e+02, 1.85659952e+00, 1.03713565e+02, 8.24113991e+03,
#        9.21106149e+02, 5.11591158e+03, 7.04618302e+03, 4.68426089e+03,
#        9.33184960e+03, 6.64310496e+03, 6.65515941e+03, 6.10026539e+03,
#        6.88749286e+03, 5.69017877e+03, 4.73586715e+03, 5.11622859e+03,
#        7.01102816e+03, 3.88814210e+03, 5.98405858e+03, 4.74605973e+03,
#        6.90024205e+03, 2.80681393e+03, 4.97786750e+03, 2.37270719e+03,
#        2.43449592e+03, 4.16490690e+03, 5.84186588e+03, 3.89905601e+03,
#        4.31884992e+03, 3.46421949e+03, 2.10325416e+03, 4.41083320e+03,
#        2.96016101e+03, 3.57927310e+03, 6.99322642e+03, 3.17771220e+03,
#        3.25596166e+03, 1.82403832e+03, 2.82337414e+03, 5.75582836e+03,
#        2.85542726e+03, 3.74838241e+03, 3.14325788e+03, 5.31394543e+02,
#        1.93031682e+03, 1.67799805e+03, 2.14638754e+03, 1.00374805e+03,
#        1.26799921e+03, 1.00616371e+03, 1.05966755e+03, 1.05608111e+03,
#        8.06191678e+02, 1.92669594e+03, 7.26444310e+02, 1.03709433e+03,
#        5.59645997e+02, 1.94553372e+03, 5.82311660e+02, 1.13968615e+03,
#        1.11822168e+03, 1.00558483e+03, 1.78019350e+03, 1.15524585e+03,
#        6.99086701e+02, 5.72656811e+02, 6.42645474e+02, 5.32076301e+02,
#        8.63425976e+01, 4.75072963e+02, 4.34495148e+02, 8.01720881e+02,
#        1.06069591e+03, 1.77842037e+03, 6.83270950e+02, 1.76434363e+02,
#        3.97093309e+02, 2.01620844e+03, 6.66669834e+02, 3.36096067e+02,
#        1.87371606e+03, 2.44871612e+02, 1.60560009e+02, 3.38657896e+02,
#        1.02140828e+03, 7.17531399e+02, 4.13707482e+02, 1.70563896e+03,
#        9.45079307e+02, 8.56024138e+02, 1.08091032e+03, 3.87330394e+02,
#        5.92210997e+02, 1.40839139e+03, 1.06647497e+03, 3.22885065e+02,
#        1.09997065e+03, 1.11297156e+03, 3.25072465e+02, 1.09582281e+03,
#        1.55553576e+03, 6.30272840e+02, 5.16481838e+02, 9.53265048e+02,
#        7.70593603e+01, 9.37183495e+01, 3.37575847e+02, 2.64522836e+02,
#        2.68616304e+02, 8.97911026e+02, 2.88090783e+02, 3.47869385e+02,
#        7.15085263e+02, 3.87355379e+02, 4.17091408e+02, 1.20059256e+03,
#        2.53291139e+02, 5.23526529e+02, 1.52961542e+03, 1.65844416e+02,
#        8.16848165e+01, 4.39241445e+02, 1.14442788e+02, 5.25584454e+02,
#        1.02667432e+02, 2.51267224e+02, 6.99707981e+01, 3.73697513e+02,
#        4.56623070e+02, 4.31544387e+02, 8.24529696e+02, 1.22281934e+02,
#        6.49903273e+02, 1.84557073e+02, 1.13617996e+03, 5.32334799e+02,
#        1.68165589e+01, 8.04110274e+02, 4.87943510e+02, 9.16575657e+02,
#        1.04215005e+02, 3.86936661e+02, 4.05115971e+01, 2.92804506e+00,
#        3.20530573e+02, 9.29994718e+00, 5.52742586e+02, 7.88830708e+02,
#        1.59665535e+02, 2.18556851e+02, 4.88611834e+02, 1.30002537e+00,
#        1.43375614e+02, 1.67648680e+00, 6.70233634e+01, 3.19158061e+02,
#        1.99915380e+02, 5.88653260e+02, 2.19673909e-02, 7.09270714e+01,
#        1.27856918e+02, 4.49895310e+01, 7.26693802e+01, 1.69146770e+02,
#        1.04159935e-03, 2.01799147e+02, 3.23830551e+01, 3.57318442e+01,
#        2.34593922e+02, 9.20671076e+01, 1.88021356e+01, 1.09703318e+02,
#        1.26742560e+03, 2.96118016e+02, 6.57819167e+02, 4.93755773e-04,
#        6.76153804e+00, 6.15080975e+02, 1.96152470e+01, 8.29607909e-04,
#        1.40078265e-03, 6.56339269e+02, 1.40452746e+02, 1.57577076e+01,
#        1.81376797e+01, 2.14253353e+01, 5.91388443e-04, 3.43017213e-04,
#        7.75770204e+01, 4.77082098e-04, 1.61435140e-03, 1.62775355e+01,
#        6.75142169e+01, 6.29272324e-04, 2.00649884e+02, 4.39085872e+01,
#        4.35733820e-04, 2.00234411e+01, 2.10188097e+00, 2.05519493e+02,
#        7.59927830e+00, 5.73161791e+00, 6.91636844e+00, 1.56676616e+01,
#        1.56423658e-04, 6.97884810e+01, 8.94647378e-04, 3.39970273e+02,
#        4.51708558e+00, 5.45573697e-04, 2.66539672e+02, 6.30557967e+01,
#        4.14350114e+02, 1.49260409e+00, 3.97873226e-04, 4.59600926e-04,
#        3.71451957e+00, 2.90336068e+02, 4.78365630e+01, 7.93459627e+01,
#        5.15383481e+01, 2.71572085e+02, 3.49509877e-05, 1.29496846e+00,
#        1.20665274e+00, 1.81657683e+02, 4.33795530e-04, 3.54726985e-04,
#        1.58741038e+00, 3.14253053e+01, 2.21663092e+00, 2.49339928e+00,
#        5.02288293e-04, 4.58133124e+01, 1.33938506e+01, 7.96326973e+00,
#        1.01709785e+00, 9.77284066e+00, 5.34886220e+01, 2.78462332e-04,
#        1.43016511e+02, 1.35355849e+01, 5.05556417e+01, 6.37870618e-01,
#        5.26394965e+01, 3.15214191e+00, 4.73026321e+01, 5.17783030e+01,
#        5.34794676e+01, 1.14963617e+02, 2.59266971e+00, 3.00495716e+00,
#        5.27760316e+01, 1.41956658e+00, 4.08598932e+01, 1.02626070e-03,
#        1.17924950e-03, 2.15877719e+00, 4.79108979e-04, 1.41642288e-04,
#        9.76635836e-04, 4.70903893e+00, 9.58377567e-04, 7.49145445e-04,
#        5.83000798e-04, 7.90779576e-04, 3.55720616e+02, 2.95974672e-04,
#        9.96247294e+00, 3.74594323e-04, 1.93740919e+02, 9.96322350e-04,
#        2.52878717e-04, 9.14475784e+01, 1.03831328e-03, 1.01025400e-03,
#        1.17971802e-03, 4.23117785e+01, 6.83639272e-04, 1.19356340e+00,
#        3.77840318e-01, 7.60326444e-04, 8.74818847e-04, 7.61399004e+01,
#        7.43599168e-04, 9.34503226e-05, 5.05467676e-01, 7.85534173e-04,
#        1.18454616e+01, 9.25244861e-01, 1.66467702e+01, 8.58181309e+01,
#        1.19116073e-03, 5.63614015e-01, 5.62644203e-04, 1.59385568e+00,
#        8.76836467e-01, 8.11687502e-04, 7.20127144e-04, 3.09142625e+01,
#        1.15635882e+02, 4.89710810e-04, 5.54537136e-04, 6.30521342e-04,
#        9.91114240e-04, 4.87640153e-04, 6.84994241e-04, 2.36349367e-04,
#        6.05232339e-04, 6.53971473e-04, 4.35800994e-04, 4.07055810e-04,
#        3.82723294e-04, 3.28070638e-04, 2.50342068e-04, 5.16233990e-04,
#        3.82479597e-04, 1.11742120e-03, 1.47178343e-03, 6.46213784e-04,
#        2.18890126e-03, 1.46268861e-03, 1.17670410e-03, 9.44875465e-04,
#        3.57207065e-04, 8.79278453e-04, 8.53221442e-04, 1.44652286e-04,
#        1.11409481e-03, 3.54543068e+01, 1.99561136e-04, 5.04686197e-04,
#        2.15436809e-04, 1.03444451e+01, 2.34859662e-04, 1.08270020e-03,
#        1.23201945e-03, 3.80102517e-04, 5.11747160e-04, 2.82781509e-04,
#        2.61508197e-04, 2.48600704e-04, 4.35762561e-04, 1.02212477e-03,
#        2.66490455e-04, 7.66966657e-05, 1.45452726e-04, 1.16952581e-03,
#        7.83520209e-04, 5.07286349e-04, 4.39706834e-05, 3.79346227e-04,
#        9.04273714e-04, 8.16243500e-04, 2.22752283e-04, 6.58168984e-04,
#        1.90265789e-04, 5.28472478e-04, 3.37175962e-04, 2.39084061e-04,
#        3.31855643e-04, 1.01078922e-04, 1.05339492e-04, 2.24436381e-04,
#        5.55759854e-04, 2.15122868e-04, 3.75408061e-04, 2.13769241e-04,
#        1.71112553e-04, 5.15781767e-04, 1.08787470e-03, 4.21498629e-04,
#        5.72046678e-04, 4.85733658e-04, 1.36831172e-03, 1.32981556e-03,
#        3.35523700e-04, 6.23789044e-05, 5.42998073e-04, 1.60054337e-04,
#        9.98575868e-04, 1.99824488e-04, 2.73195029e-04, 2.11597299e-04,
#        3.23523561e-04, 1.51249885e-04, 2.97529264e-04, 4.30103950e-04,
#        1.15403985e-04, 1.26625994e-04, 1.28382469e-04, 4.88660376e-04,
#        2.91018438e-04, 5.83421342e-04, 2.40035415e-04, 7.30868235e-04,
#        5.14608967e-04, 1.58657784e-04, 2.15062590e-04, 1.35854283e-03,
#        5.12114202e-05, 2.58493976e-04, 6.07348620e-04, 9.18843690e-05,
#        4.41901459e-04, 6.33932199e-04, 1.11695209e-03, 9.36585560e-05,
#        8.46489963e-04, 5.65659950e-05, 5.61828282e-04, 4.95891832e-05,
#        1.35187368e-04, 5.71508285e-04, 1.55770711e-04, 8.85462916e-04,
#        2.62918460e-04, 4.68972357e-04, 8.40576848e-04, 1.13532171e-04,
#        1.93697343e-04, 4.01440334e-04, 1.14353651e-04, 2.10881506e-04,
#        4.36835605e-04, 3.58547799e-04, 6.10805741e-04, 4.84963053e-04,
#        1.31729240e-04, 9.74390226e-05, 5.21117099e-05, 5.62869902e-04,
#        4.20221864e-04, 2.67440680e-04, 7.63943750e-04, 2.69432869e-04,
#        3.55674263e-07, 1.55196551e-04, 8.17391337e-04, 5.07080473e-05,
#        1.47139633e-07, 4.39908334e-04, 5.21152652e-04, 1.04627353e-03,
#        8.12411795e-04, 7.65524500e-04, 0.00000000e+00, 7.25268222e-04,
#        3.08756226e-04, 1.35029596e-04, 2.15635342e-05, 6.52754381e-04,
#        3.26090817e-04, 6.25124614e-05, 8.94846696e-05, 1.16888861e-03,
#        3.66120406e-05, 4.23534210e-04, 1.26583497e-03, 1.66036738e-05,
#        3.27978104e-04, 3.69011089e-05, 8.56148779e-05, 1.42065471e-04,
#        4.23854514e-05, 5.00038801e-05, 2.29942355e-04, 6.47069700e-05,
#        1.15865328e-06, 1.79258970e-04, 1.80447403e-04, 4.90078965e-04,
#        2.88386135e-04, 1.21531888e-03, 3.04926879e-04, 1.71797850e-04,
#        6.43857160e-04, 2.48218301e-04, 2.50434458e-04, 3.44089182e-05,
#        4.59030656e-04, 2.02033563e-04, 6.77723379e-04, 3.06964699e-04,
#        5.72043784e-04, 2.75783538e-04, 1.98150902e-05, 0.00000000e+00,
#        2.99450656e-04, 1.13760641e-05, 3.72330296e-04, 1.50894710e-04,
#        2.54457034e-04, 2.42665461e-03, 2.00695808e-04, 1.17262128e-04,
#        6.86169539e-06, 0.00000000e+00, 1.97671188e-05, 5.50955141e-05,
#        6.74687673e-04, 1.39841018e-04, 6.33979853e-04, 6.26749461e-05,
#        2.45720482e-04, 8.47706292e-04, 2.26907096e-06, 2.34655579e-04,
#        4.10190159e-05, 8.28842518e-06, 1.45346737e-04, 4.05515127e-05,
#        3.78688905e-04, 2.59766589e-04, 2.84140116e-05, 1.24180530e-04,
#        2.74608893e-05, 5.09260016e-04, 3.76883020e-07, 2.38410959e-04,
#        5.94739056e-04, 7.99413952e-04, 1.62846569e-07, 0.00000000e+00,
#        2.57337379e-04, 6.24910261e-04, 2.24884907e-05, 5.06462909e-04,
#        1.79837935e-04, 1.35749097e-04, 7.88452685e-05, 2.61619217e-04,
#        4.74093879e-04, 5.10899047e-04, 0.00000000e+00, 6.90693594e-05,
#        1.75093561e-04, 6.44453870e-04, 5.10505897e-05, 1.47632059e-06,
#        1.96782445e-04])

# %%
for rho_times_w in (2,):
    plot(var='cloud water mixing ratio', qlabel='cloud water mixing ratio [g/kg]', fname=f'qc_rhow={rho_times_w}.pdf',
            output=output[f'rhow={rho_times_w}.0'],
            line = {0: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./qc_rhow=2.pdf' target='_blank'>./qc_rhow=2.pdf</a><br>")

# %%
for rho_times_w in (2,):
    plot(var='nc', qlabel='cloud water number concentration', fname=f'nc_rhow={rho_times_w}.pdf',
            output=output[f'rhow={rho_times_w}.0'],
            line = {0.01: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./nc_rhow=2.pdf' target='_blank'>./nc_rhow=2.pdf</a><br>")

# %%
p = True
for rho_times_w in (2,):
    plot(var='rain water mixing ratio', qlabel='rain water mixing ratio [g/kg]', fname=f'qr_rhow={rho_times_w}.pdf',
         output=output[f'rhow={rho_times_w}.0'],
         line = {0: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./qr_rhow=2.pdf' target='_blank'>./qr_rhow=2.pdf</a><br>")

# %%
for rho_times_w in (2,):
    plot(var='nr', qlabel='rain water number concentration', fname=f'nr_rhow={rho_times_w}.pdf',
            output=output[f'rhow={rho_times_w}.0'],
            line = {0.01: ":", 4: "--", 8: "-", 12: "-."})
# Out:
# HTML(value="<a href='./nr_rhow=2.pdf' target='_blank'>./nr_rhow=2.pdf</a><br>")

# %%
p = True
for rho_times_w in (2,):
    key = f"rhow={rho_times_w}.0"
    filename = 'products_' + key + 'collisions_golovin.nc'
    nc_exporter = NetCDFExporter_1d(output[key], settings[key], simulation[key], filename)
    nc_exporter.run()
